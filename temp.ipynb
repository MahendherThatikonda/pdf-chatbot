# %%
2+2
# Out:
# 4

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("DATA605_Foleys3_final_report (3).pdf")
pdf_docs=loader.load()
pdf_docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 0, 'page_label': '1'}, page_content='Plumbing AI Compliance Assistant: A\n Retrieval- Augmented Generation \nProof of Concept \n \n \n \n \n \nUniversity University of Canterbury \nDegree Master of Applied Data Science \nCourse DATA605-25X – Industry Based Research Project \nIndustry Foleys \nPrimary Supervisor Phil Davies \nSecondary Supervisor Yiwen Lyu \nIndustry Supervisors Gwen Slote \nGroup members Nirosigaa Subendran (98402523) \nMahendher Thatikonda (16485324)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 1, 'page_label': '2'}, page_content='Executive Summary \nFoleys staff regularly need quick, reliable answers from New Zealand plumbing and building \ncompliance documents while planning work, quoting, ordering materials, or resolving on -site \nquestions. In practice, those answers are buried across multiple standard s and Building Code \nguidance, and the work often depends on time -consuming manual searches and informal \nknowledge held by senior staff. This project developed a proof -of-concept Compliance AI \nAssistant to reduce search time while preserving accountability through evidence -based \nresponses.  \n \nThe system was built using a Retrieval-Augmented Generation (RAG) approach in which official \ndocuments act as the sole source of truth. A fixed corpus of 27 compliance documents was \nestablished and processed into chunked, metadata-rich records with page-level traceability. The \nfinal ingestion workflow uses fast page -based extraction, conservative text normalisation, and \ntoken-aware chunking. Each chunk is indexed in Pinecone using two complementary indexes: a \ndense semantic index and a sparse lexical index.  At query time, the system retrieves 20 \ncandidates from each index, merges and deduplicates results, then applies Pinecone reranking \nto select the top five evidence passages for answer generation using gpt-4.1-mini.  \n \nEvaluation using representative questions provided by Foleys showed stable retrieval behavior \nand generally strong answer quality when the relevant clause or table was retrieved. The assistant \nproduced structured outputs that separate AS/NZS requirements f rom New Zealand Building \nCode (NZBC) material and includes exact evidence quotes with page -level S3 links in the form, \nenabling direct verification. When evidence was insufficient, the system stated limitations rather \nthan guessing. End -to-end latency was acceptable for proof -of-concept, with generation time \ncontributing most variability. Overall, the prototype demonstrates that an evidence-grounded RAG \nassistant can act as a practical navigation layer over compliance documents, while highlighting \nthe need for continued work on retrieval coverage, ambiguity handling, and larger-scale validation.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='Table of Contents \nExecutive Summary ................................ ................................ ................................ ................... 2 \nTable of Contents ................................ ................................ ................................ ....................... 3 \nList of Figures ................................ ................................ ................................ ............................ 5 \n1. Introduction ................................ ................................ ................................ ............................ 6 \n2. Problem Statement ................................ ................................ ................................ ................ 6 \n3. Project Aims and Scope ................................ ................................ ................................ ......... 7 \n3.1 Aims ................................ ................................ ................................ ................................ . 7 \n4. Background and Standards Context ................................ ................................ ....................... 8 \n4.1 Performance-based regulation and compliance pathways ................................ ................ 8 \n4.2 Standards versions and practical interpretation ................................ ................................  8 \n5. Method ................................ ................................ ................................ ................................ ... 9 \n5.1 Overall approach ................................ ................................ ................................ .............. 9 \n5.2 System Architecture Overview ................................ ................................ .......................... 9 \n5.3 Database Design and Data Storage ................................ ................................ ................10 \n5.3.1 PostgreSQL (Relational Storage) ................................ ................................ ..............10 \n5.3.2 MongoDB Atlas (Document Storage) ................................ ................................ ........11 \n5.3.3 Pinecone (Vector Database for Retrieval) ................................ ................................ .11 \n5.4 Document Ingestion Pipeline ................................ ................................ ...........................11 \n5.4.1 Document Upload and Source Management ................................ .............................11 \n5.4.2 PDF Text Extraction ................................ ................................ ................................ ..11 \n5.4.3 Text Cleaning and Normalisation ................................ ................................ ..............12 \n5.4.4 Metadata Construction and Version Context ................................ .............................12 \n5.4.4 Token-Aware Chunking ................................ ................................ .............................12 \n5.4.5 Vector Indexing and Upload ................................ ................................ ......................13 \n5.4.6 Upload Process and Metadata Consistency ................................ .............................. 14 \n5.4.6 Evidence Preservation and Traceability ................................ ................................ ....14 \n5.5 RAG Pipeline Implementation ................................ ................................ ..........................15 \n5.5.1 Hybrid Retrieval Strategy ................................ ................................ ..........................15 \n5.5.2 Reranking for Rele ...
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='5.6 User Interaction Flow ................................ ................................ ................................ .......18 \n5.6.1 User Authentication and Session Management ................................ .........................18 \n5.6.2 Real-Time Chat Communication ................................ ................................ ...............18 \n5.6.3 Query Processing and RAG Invocation ................................ ................................ .....19 \n5.6.4 Answer Generation and Streaming Response ................................ ...........................19 \n5.6.5 Citation Handling and Source Navigation ................................ ................................ ..19 \n5.6.6 Conversation and Message Persistence ................................ ................................ ...20 \n5.6.7 Feedback Collection and Storage ................................ ................................ .............20 \n6. Data ................................ ................................ ................................ ................................ ......20 \n6.1 Data Sources and Composition ................................ ................................ .......................20 \n6.2 Document Diversity ................................ ................................ ................................ .........21 \n6.3 Data Summary Visualisation ................................ ................................ ............................21 \n6.4 Relevance to the RAG Approach ................................ ................................ .....................22 \n7. Results ................................ ................................ ................................ ................................ ..23 \n7.1 Question Coverage and Retrieval Performance ................................ ............................... 23 \n7.2 Answer Quality and Evidence Grounding................................ ................................ .........24 \n7.3 Handling of Ambiguity and Missing Information ................................ ............................... 25 \n7.4 System Responsiveness ................................ ................................ ................................ .27 \n8. Outcomes ................................ ................................ ................................ .............................27 \n8.1 Primary Project Outcomes ................................ ................................ ............................... 27 \n8.2 Technical Outcomes ................................ ................................ ................................ ........28 \n8.3 Evaluation Outcomes................................ ................................ ................................ .......28 \n8.4 Practical Outcomes for Foleys ................................ ................................ .........................29 \n8.5 Limitations and Scope of Outcomes ................................ ................................ ................29 \n9. Conclusion ................................ ................................ ................................ ............................30 \n10. Future Work ................................ ................................ ................................ ........................30 \nReferences ................................ ................................ ................................ ............................... 31 \nAcknowledgements ................................ ................................ ................................ ...................32 \nAppendices .................... ...
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='Pinecone Chunk record metadata (stored in both dense and sparse indexes) ...................35 \nAppendix C: User Interface Design ................................ ................................ ........................36 \nAppendix D: AWS S3 Bucket ................................ ................................ ................................ .40 \nAppendix E: Postgres Table ................................ ................................ ................................ ..41 \nAppendix F: MongoDB Collection ................................ ................................ ..........................42 \nAppendix G: LLM Prompt ................................ ................................ ................................ ......44 \n \nList of Figures \nFigure 1- System Architecture ................................ ................................ ................................ ...10 \nFigure 2 - User Query Flow ................................ ................................ ................................ .......18 \nFigure 3 - Data Summary ................................ ................................ ................................ ..........22 \nFigure 4 - Login page ................................ ................................ ................................ ................36 \nFigure 5 -  Chat page ................................ ................................ ................................ ................36 \nFigure 6 - Chat response ................................ ................................ ................................ ..........37 \nFigure 7 - PDF Navigation ................................ ................................ ................................ .........37 \nFigure 8 - Admin dashboard(Analytics) ................................ ................................ .....................38 \nFigure 9 - Admin dashboard(Feedback List) ................................ ................................ .............38 \nFigure 10 – Chat detail page ................................ ................................ ................................ .....39 \nFigure 11 - S3 Bucket for PDF Storage ................................ ................................ .....................40 \nFigure 12 - S3 Bucket Public Policy ................................ ................................ ..........................40 \nFigure 13 - conversation_analytics postgres table ................................ ................................ .....41 \nFigure 14 - feedback_analytics postgres table ................................ ................................ ..........41 \nFigure 15 - users postgres table ................................ ................................ ................................ 42 \nFigure 16 - conversations mongo collection ................................ ................................ ..............42 \nFigure 17 - messages mongo collection ................................ ................................ ....................43 \nFigure 18 - message_feedback mongo collection ................................ ................................ .....43 \nFigure 19 - LLM System Prompt ................................ ................................ ............................... 44 \nFigure 20 - LLM User Prompt ................................ ................................ ................................ ....44'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 5, 'page_label': '6'}, page_content='1. Introduction \nCompliance work in the building and plumbing industry is not only technical, it is also time \nsensitive. In Foleys’ context, staff may need to confirm requirements while planning jobs, quoting, \nordering materials, or deciding what is acceptable on-site. These questions are rarely phrased in \nthe same way standards are written. People ask in everyday language, they shorten terms, they \nuse trade shorthand, and they often start with a partial idea rather than a clean specification. \n \nAt the same time, New Zealand building regulations and supporting compliance documents are \ncomplex, and they are designed to be interpreted within a compliance framework  (Ministry of \nBusiness, Innovation & Employment, 2014). Building regulations are performance-based, so they \ndescribe what must be achieved rather than prescribing one exact solution. In practice, people \nrely on compliance pathways like Acceptable Solutions and Verification Methods, or they propose \nAlternative Solutions with supporting evidence. For plumbing and drainage, the AS/NZS 3500 \nstandards form a key pathway for “how to comply” under commonly used Acceptable Solutions \n(Ministry of Business, Innovation & Employment, 2026). That combination is powerful, but it also \ncreates an information problem: the relevant answer is often present, but it is buried inside a large \nset of documents, and the user needs to find it quickly and interpret it correctly. \n \nThis project sets out to design a Retrieval -Augmented Generation assistant that makes \ncompliance information easier to access while preserving accountability. The goal was not to \nreplace professional judgement or regulatory responsibility. It was to reduce time spent searching, \nimprove consistency in referencing authoritative documents, and create a more transparent way \nto answer common questions, including links and citations so users can verify the source. \n2. Problem Statement \nFrom discussions with the project context and typical operational realities, the core problem can \nbe summarised as follows: \n• Manual searching is slow and disruptive. Locating answers within technical standards \noften involves repeated keyword searches, extensive scrolling, and cross -referencing \nacross multiple PDF documents. \n• Regulations are hard to navigate. Standards and Acceptable Solutions are drafted for \naccuracy, not for quick search by time-pressed staff.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 6, 'page_label': '7'}, page_content='• Compliance risk carries real cost. Misinterpretation or overlooking a requirement can \ncause rework, delays, failed inspections, penalties, and serious long -term reputational \ndamage. \n• Knowledge can be concentrated in senior staff . When answers depend on a small \ngroup of experienced people, it creates a bottleneck and increases the risk of inconsistent \nadvice when those staff are unavailable. \n• Version changes add uncertainty . Differences between editions (for example, 2022 \nversus 2025 editions) can create confusion, especially when newer editions are not yet \nreferenced by legislation but may still be used as Alternative Solutions. \n \nThis is fundamentally a data and decision -support problem: how can we retrieve the right \nevidence from authoritative documents quickly, then present it in a way that users trust and can \naudit. \n3. Project Aims and Scope \n3.1 Aims \nThe project aimed to build and test a proof-of-concept that can: \n1. Standards Retrieval : Allow users to ask natural language questions and receive \naccurate, up-to-date answers grounded in official compliance documents. \n2. Contextual Understanding: Handle paraphrasing and variations in how questions are \nasked, and request clarification when queries are ambiguous. \n3. Document Navigation : Provide citations and deep links to relevant sections, and \nsummarise long sections into concise, actionable points. \n4. Multi-format Support : Return text answers and optionally provide downloadable \nreferences (such as PDF links or supporting diagrams, when available). \n5. Updated Standards Awareness: Summarise changes between document versions and \nnote the compliance status (for example, when an edition is not yet referenced by the \nBuilding Code but could be used as an Alternative Solution). \n6. Feedback Loop: Enable users to rate responses or flag inaccuracies, supporting iterative \nimprovement.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 7, 'page_label': '8'}, page_content='4. Background and Standards Context \n4.1 Performance-based regulation and compliance pathways \nNew Zealand building regulations operate on a performance basis. This means the law describes \noutcomes that must be achieved (for example, water systems must be safe and hygienic), rather \nthan prescribing a single method. Compliance pathways support how those outcomes are shown \nin practice: \n• Acceptable Solutions: Prescriptive paths that, if followed, are accepted as compliant. \n• Verification Methods: Methods based on testing or calculations that are used to show \ncompliance. \n• Alternative Solutions: Different approaches that can be put forward and justified using \nsupporting evidence. \nIn day-to-day plumbing practice, AS/NZS standards are relied on as a practical guide for applying \nrequirements in real situations. The AS/NZS 3500 series is commonly regarded as the primary \nreference for plumbing and drainage work (Ministry of Business, Innovation & Employment, 2021) \n. Alongside this, Building Code linkage documents and Acceptable Solutions, including those \nrelated to the G12 Water Supplies area, are regularly used within the industry and help bring \nstructure to what would otherwise be a wide and technically demanding set of standards (Ministry \nof Business, Innovation & Employment, 2026). \n4.2 Standards versions and practical interpretation \nA practical issue arises from the fact that multiple editions of the same standard can exist, while \nonly certain versions are referenced within Acceptable Solutions at any given time  (Ministry of \nBusiness, Innovation & Employment, 2026). Within the context of this project: \n• The 2021/2022 editions were treated as the current Acceptable Solutions reference point \n(Ministry of Business, Innovation & Employment, 2014). \n• 2025 editions were noted as not yet referenced by legislation but could still be used as \nAlternative Solutions. \n• Older editions (for example 2018 versions in some cases) were considered superseded \nand not recommended as the main compliance reference. \nThis matters for a RAG assistant bec ause the system must not only retrieve text, it must also \ncommunicate the status and context of that text.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 8, 'page_label': '9'}, page_content='5. Method \n5.1 Overall approach \nThis project followed a data -centric approach to the development of a proof -of-concept \nCompliance AI Assistant for New Zealand building and plumbing standards. Rather than aiming \nfor open -ended conversation, the emphasis was placed on supporting compliance -related \ndecision making by ensuring accurate information retrieval and the clear, transparent presentation \nof authoritative sources. \n \nThe system was designed using a RAG paradigm, where official standards documents form the \nsole source of truth. Large Language Models (LLM) are used only to synthesise and summarise \nretrieved content, rather than to generate answers independently. This ensures that responses \nremain grounded in verifiable evidence. \n \nThe work followed a three -stage process. The process started by defining a fixed collection of \nofficial compliance documents and converting them into a searchable format, while still \nmaintaining page-level traceability. The next stage then focused on developing a hybrid retrieval \nstrategy that combined semantic search with lexical matching, enabling the system to respond to \nboth everyday language questions and more specialised technical terminology. In the final stage, \na controlled generation layer was used  to generate structured responses, with each answer \nclearly supported by citations that pointed back to the original source documents. \n \nOverall, this approach mirrors the way compliance tasks are carried out in real settings, where \nclarity, accuracy, and traceability matter, and it tre ats the system as a tool to support decision \nmaking rather than something intended to replace professional judgement. \n5.2 System Architecture Overview \nThe system is built using a multi -tier architecture that separates the user interface, application \nlogic, and data storage. A Next.js frontend is used to deliver the chat interface and admin \ndashboard, while a FastAPI backend runs the RAG pipeline through a combination of \nWebSockets and REST Application Programming Interface (API) . Information retrieval is \nmanaged through Pinecone hybrid search, using both a dense index and a sparse index with \nreranking, and OpenAI gpt-4.1-mini is used to generate the final responses with evidence-based'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 9, 'page_label': '10'}, page_content='citations. PostgreSQL is used to store user data and structured analytics, while MongoDB Atlas \nholds conversation histories, messages, and feedback. PDF documents are uploaded to AWS \nS3, and citations are linked to the exact source pages. \n \nFigure 1- System Architecture \n5.3 Database Design and Data Storage \nThe system uses a hybrid data storage approach to accommodate both structured operational \ndata and more flexible conversational data. Relational  data storage is applied in areas where \nconsistency, data integrity, and analytical querying are important, while document-based storage \nis used to manage conversational context and message -level metadata. A separate vector \ndatabase is employed to enable effective retrieval across the compliance document corpus. \n5.3.1 PostgreSQL (Relational Storage) \nPostgreSQL is used to store user accounts and structured analytics data. This database \nunderpins core system functions such as authentication, role -based access control, \nadministrative reporting, and overall system monitoring. The data held in PostgreSQL follow a \nrelatively stable structure and are well suited to relational constraints and indexing, which supports \nconsistency and efficient querying. Postgres schema see in appendix.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 10, 'page_label': '11'}, page_content='5.3.2 MongoDB Atlas (Document Storage) \nMongoDB Atlas is used to store conversational data, which is naturally hierarchical and benefits \nfrom a flexible schema  (MongoDB, n.d.). This database captures the full chat history, message \nsequencing, and detailed metadata associated with each assistant response. MongoDB schema \nsee in appendix. \n5.3.3 Pinecone (Vector Database for Retrieval) \nPinecone is used to store and retrieve document chunks for the retrieval -augmented generation \npipeline. Two separate indexes are maintained to enable hybrid retrieval (Pinecone Systems, Inc, \nn.d.). Pinecone metadata schema see in appendix. \n5.4 Document Ingestion Pipeline \nThe document ingestion pipeline transforms compliance PDFs into a structured and searchable \nrepresentation that supports retrieval -augmented generation while preserving traceability to \noriginal source documents. The pipeline was designed with a strong emph asis on regulatory \ntransparency, reproducibility, and alignment with LLM  constraints. \n5.4.1 Document Upload and Source Management \nAll compliance documents are uploaded manually to an AWS S3 bucket and handled as \nimmutable source artefacts. This setup ensures that the system works with a fixed and auditable \nset of documents, which is particularly important in a compliance setting. AWS  S3 was chosen \nbecause it offers stable, publicly accessible URLs that can be shared directly with end users. \n \nRather than generating page -specific links during ingestion, the pipeline stores the base S3 \ndocument link together with the page number as metadata. During answer generation, these \nvalues are combined to produce citations in the format <s3-link>#page=<page_number>, \nallowing users to open the exact supporting page in the original PDF (Adobe, 2007). \n5.4.2 PDF Text Extraction \nText extraction is performed at the page level to ensure that all retrieved evidence can be traced \nback to an exact location in the source document. Early versions of the pipeline used pdfplumber \nbecause of its accuracy on complex PDF layouts. When processing large standards documents, \nthis approach proved to be computationally slow and unsuitable for repeated ingestion runs.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 11, 'page_label': '12'}, page_content='The final implementation uses PyMuPDF, which provides significantly faster page -level text \nextraction while still preserving page boundaries (PyMuPDF, n.d.). Each page is processed one \nat a time, with the extracted text explicitly linked to its corresponding page number. Maintaining \nthis link is important because the page numbers are later shown directly to users as part of the \ncitation process. \n5.4.3 Text Cleaning and Normalisation \nExtracted text is lightly cleaned to reduce noise introduced by PDF formatting. This step includes \nnormalising whitespace, collapsing excessive line breaks, and removing layout artefacts that \ncould interfere with tokenisation or embedding. Cleaning is inte ntionally conservative to avoid \naltering regulatory wording, as even minor textual changes could affect compliance interpretation. \n \nThe purpose of this step is to improve consistency across documents with different layouts rather \nthan to rewrite or summarise content. \n5.4.4 Metadata Construction and Version Context \nEach document is assigned structured metadata before chunking. Metadata fields include \ndocument title, filename, standard type, edition year, and currency status. These attributes are \ninferred based on filename conventions and recognised naming patterns commonly used in New \nZealand compliance documents. \n \nWhen multiple editions of a standard are available, the metadata records whether a document \naligns with a currently referenced Building Code edition or represents a newer version that may \nonly be applicable as an Alternative Solution. Storing this information explicitly provides important \nregulatory context during retrieval and reduces the risk of users misinterpreting answers. \n5.4.4 Token-Aware Chunking \nChunking is carried out using a token-aware strategy that is aligned with the tokenisation scheme \nof the OpenAI language model used for answer generation. The system applies the cl100k_base \ntoken encoding (OpenAI, n.d.), which is consistent with the token units used by OpenAI models \nwhen determining context length and token limits  (OpenAI, 2022). As a result, the chunk sizes \ndefined during ingestion directly reflect how the language model later interprets and processes \ntext at inference time.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 12, 'page_label': '13'}, page_content='A token-based approach was chosen instead of character-based chunking to avoid mismatches \nbetween preprocessing and generation. Character counts are a poor proxy for actual model \ncontext usage, particularly in regulatory documents that include symbols, tab les, and technical \nformatting. By working in token space, the pipeline is able to keep each chunk within a predictable \nand safe portion of the model’s effective context window (Maryamah, et al., 2024). \n \nAs part of the ingestion stage, chunks are created to be roughly 1,740 tokens in length, with a \n205-token overlap between neighboring chunks. These parameters were set to manage the trade-\noff between retrieving enough relevant information and keeping proce ssing costs reasonable. \nSetting the chunk size to 1,740 tokens allows related regulatory content, such as full clauses or \nexplanations linked to tables, to remain grouped together without creating chunks that are too \nlarge for reliable semantic matching. W here content extends across chunk boundaries, a 205 -\ntoken overlap is introduced between neighbouring chunks. This approach helps preserve \nmeaning across splits and lowers the risk that the retrieval step returns only partial or \ndisconnected evidence. \n5.4.5 Vector Indexing and Upload \nAfter chunking and metadata construction are completed, all document segments are indexed in \nPinecone, which functions as the system’s vector database for retrieval. Pinecone was chosen \nbecause it supports scalable vector search, hybrid retrieval approache s, and metadata -aware \nquerying, all of which are important when working with large collections of regulatory documents. \n \nTo support different but complementary retrieval behaviors, the system maintains two separate \nPinecone indexes: one dense semantic index and one sparse lexical index. Both indexes are \ndeployed on AWS in the us-east-1 region and run in on-demand capacity mode, which allows the \nsystem to scale automatically with query volume without the need for manual capacity planning. \n \n• Dense Vector Index \nThe dense index is intended to model semantic similarity between user queries and individual \ndocument chunks. Each chunk is embedded using the llama-text-embed-v2 model, which \ngenerates fixed -length vector representations with a dimensionality of 1024. This makes it \npossible for the system to retrieve conceptually relevant sections even when the user’s phrasing \ndiffers from the language used in the standards documents.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 13, 'page_label': '14'}, page_content='In addition to the embeddings themselves, the dense index also stores the relevant metadata for \neach chunk. This metadata includes the document title, filename, standard type, edition year, \ncurrency status, page number, and the base S3 file link. Keeping m etadata together with the \nembeddings makes it possible to apply filters and generate citations later without needing extra \nlookup steps. \n \n• Sparse Vector Index \nIn parallel, all chunks are indexed in a sparse Pinecone index using the pinecone-sparse-\nenglish-v0 model. This index supports lexical -style retrieval based on term overlap and exact \nkeyword matching. Unlike traditional BM25 implementations, this approach uses Pinecone’s \nmanaged sparse embedding model, allowing sparse and dense retrieval to be handled \nconsistently within the same infrastructure (Pinecone Systems, Inc, n.d.). \n \nThe sparse index stores identical metadata fields to the dense index. This symmetry allows results \nfrom both retrieval modes to be merged and compared directly, while still maintaining consistent \ndocument references and citation information. \n5.4.6 Upload Process and Metadata Consistency \nDuring ingestion, each chunk is uploaded to both the dense and sparse indexes using a shared \nnamespace. Chunk identifiers are generated deterministically to avoid duplication and to maintain \na stable mapping between chunks across indexes. Uploading the sam e chunk content and \nmetadata to both indexes ensures that semantic and lexical retrieval operate over the same \nunderlying evidence base. \n \nCrucially, each indexed record includes both the base S3 document link and the page number \nfrom which the chunk was extracted. These fields are not combined during indexing. Rather than \nbeing joined earlier in the pipeline, they are exposed independently d uring retrieval and brought \ntogether only at the answer generation stage to form page -level citation links in the format <s3 -\nlink>#page=<page_number>. This approach keeps the system flexible while still allowing \ncitations to remain precise and easy to verify. \n5.4.6 Evidence Preservation and Traceability \nFrom early on in development, traceability was treated as something the ingestion pipeline had \nto support rather than an optional feature. Each chunk indexed in Pinecone keeps track of the'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 14, 'page_label': '15'}, page_content='document it was taken from, along with the relevant page number. When an answer is produced, \nthis information is passed through to the user as citations, so it is always possible to check the \nresponse against the exact page in the original PDF. \n \nThrough the combination of page -level extraction, token -aware chunking, and structured \nmetadata, the ingestion pipeline ensures that the assistant operates as an evidence -grounded \nnavigation layer over official compliance documents, rather than as an opaqu e text generation \nsystem. \n5.5 RAG Pipeline Implementation \nThe retrieval -augmented generation (RAG) pipeline integrates hybrid document retrieval with \ncontrolled answer generation to provide accurate, evidence-grounded responses to user queries \nabout New Zealand building and plumbing standards. The design prioriti ses relevance, \ntransparency, and traceability, which are essential in a compliance-focused domain where users \nmust be able to verify answers against official source documents. \n5.5.1 Hybrid Retrieval Strategy \nWhen a user submits a query, the system applies a hybrid retrieval process by querying both a \ndense semantic index and a sparse lexical index in parallel. Both indexes are hosted on Pinecone \nand deployed on AWS in the us-east-1 region under a shared namespace, building-standards. \n \nThe dense index ( foleys3-rag-dense-v3) is built on semantic embeddings produced by the \nllama-text-embed-v2 model, using a vector dimensionality of 1024. Its role is to retrieve \npassages that are conceptually related to a user’s query, which helps the system respond to \nnatural language questions even when the wording does not closely match the language used in \nthe regulatory documents. At the same time, the sparse index ( foleys3-rag-sparse-v3) uses \nPinecone’s managed sparse retrieval model, pinecone-sparse-english-v0, to identify passages \nwith strong lexical overlap between the query and the source text  (Pinecone Systems, Inc, \nn.d.).This is particularly important for compliance queries that rely on precise technical \nterminology (Pinecone Systems, Inc, n.d.). \n \nFrom each index, the system retrieves an initial set of 20 candidate chunks, resulting in a \ncombined pool of up to 40 candidates before merging. The results from both retrieval streams are \nmerged into a single candidate pool by deduplicating on chunk ident ifiers. If a chunk is returned'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 15, 'page_label': '16'}, page_content='by both the dense and sparse retrieval processes, the higher of the two relevance scores is kept. \nThis merging approach is used to keep potentially useful evidence in the results while avoiding \nrepeated appearances of the same passage in the candidate set. \n \nTo limit computational overhead during reranking, the combined pool of candidates is restricted \nto a maximum of 100 chunks. This constraint is intended to balance retrieval recall with efficiency, \nensuring that reranking is carried out on the most relevant candidates instead of the entire \nretrieved set. \n5.5.2 Reranking for Relevance \nTo improve ranking accuracy beyond raw vector similarity, the capped set of candidate chunks is \npassed through Pinecone’s inference -based reranking model, bge-reranker-v2-m3. This \nreranker assesses the relevance of each retrieved passage against the full user query, rather \nthan depending only on embedding similarity scores (Pinecone Systems, Inc, n.d.). \n \nReranking is applied to a maximum of 100 candidates, after which only the top 5 reranked chunks \nare kept for answer generation. Adding this extra ranking stage leads to noticeably better retrieval \nquality, particularly for complex or multi-part regulatory questions where semantic similarity on its \nown may return passages that only partially address what is being asked. \n5.5.3 Context Construction for Generation \nThe top 5 reranked passages are assembled into a structured context that is provided to the \nlanguage model. Each passage is accompanied by its associated metadata, including document \ntitle, filename, edition year, currency status, page number, and the base  S3 file link. These \nmetadata fields are deliberately retained so they can be exposed directly to the user as citations \nin the generated answer. \n \nAs part of the context construction step, a page -level citation link is formed by combining the \nstored S3 document URL with the corresponding page number, following the format \n<file_link>#page=<page_number>. This allows users to navigate directly to the relevant page \nin the original PDF for verification. \n \nThe system prompt establishes the assistant’s role as a domain expert on New Zealand building \nand plumbing standards and instructs the model to prioritise accuracy, avoid speculation, and rely'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 16, 'page_label': '17'}, page_content='strictly on the provided context. The user prompt defines a strict response structure that separates \nprimary requirements derived from AS/NZS standards from secondary or supplementary \nrequirements derived from New Zealand Building Code or linkage documents . This structured \nprompting ensures consistency across responses and helps users distinguish between different \ncompliance pathways. \n5.5.4 Answer Generation and Citation \nAnswer generation is performed using the OpenAI gpt-4.1-mini model. This model was selected \nas a balanced trade-off between reasoning capability, response reliability, and operational cost. \nIn a compliance -focused setting, the primary requirement is faithf ul summarisation of retrieved \nevidence rather than open -ended creativity. Empirical testing showed that gpt -4.1-mini \nconsistently followed structured prompts, respected evidence boundaries, and produced stable \noutputs at lower latency and cost compared to larger general-purpose models, making it suitable \nfor a production-oriented proof-of-concept. \n \nThe model is instructed to summarise requirements using bullet points and to include exact \nquoted evidence copied directly from the retrieved passages. Each quoted passage is required \nto include the filename, page number, and a clickable citation link formed from the S3 document \nURL and the corresponding page number. This design makes it possible for users to check the \ninformation for themselves, which helps build confidence in the system’s outputs. \n \nAs a result, each response includes both a structured natural language explanation and a clear \nset of source references, so that every claim can be traced back to an official standards document. \n5.5.5 Design Rationale \nThe overall RAG pipeline represents a considered balance between retrieving a broad range of \nrelevant information and producing precise, well -supported answers. Hybrid retrieval across \ndense and sparse indexes improves recall for different types of queries , reranking then refines \nrelevance using a query -aware inference model, and structured prompting is used to maintain \nclarity, consistency, and traceability in the final output. Taken together, these elements ensure \nthat the assistant is not intended to function as a general conversational system, but rather as a \ncontrolled, evidence-based interface for working through complex regulatory documentation.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 17, 'page_label': '18'}, page_content='5.6 User Interaction Flow \nThe user interaction flow outlines how users submit queries, receive responses supported by \nevidence, and provide feedback within the compliance assistant. The flow is designed to enable \nreal-time interaction, clear and transparent citation, and the persistent storage of interaction data \nso it can be analysed at a later stage. \n \nFigure 2 - User Query Flow \n5.6.1 User Authentication and Session Management \nAuthentication in the system is based on JSON Web Tokens. When a user logs in successfully, \na signed JWT is generated and stored in an httpOnly cookie. This cookie is then sent automatically \nwith all later API and WebSocket requests. As a result, the backe nd can link incoming requests \nto an authenticated user, while the token itself remains inaccessible to client-side scripts. \n5.6.2 Real-Time Chat Communication \nReal-time interaction for users is achieved via a WebSocket connection linking the Next.js \nfrontend with the FastAPI backend. Using this channel enables low -latency, two -way \ncommunication and allows partial responses to be sent back as they are produced, r ather than \nholding everything until the full response is ready. This behaviour becomes particularly noticeable \nwhen retrieval and reranking increase processing time, as streaming feedback helps the system \nfeel more responsive to the user.'),
# ...
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 30, 'page_label': '31'}, page_content='realistically on site. One possible way to address this is by placing tighter limits on generation and \nintroducing caching in parts of the pipeline where it would have the most impact. From a usability \npoint of view, the system would also benefit from lett ing users upload PDFs directly through the \ninterface, instead of depending on manual ingestion steps. Over time, adding duplicate document \ndetection would make it easier to manage sources properly and help prevent declines in retrieval \nquality as more documents are added. \n \nReferences \n• Adobe. (2007, April). Parameters for Opening PDF Files. From PDF Objects: \nhttps://pdfobject.com/pdf/pdf_open_parameters_acro8.pdf \n• Arunabh, B., & Heriberto, C. (2024). Systematic Analysis of Retrieval-Augmented \nGeneration-Based LLMs for Medical Chatbot Applications. Machine Learning & \nKnowledge Extraction, 2356-2356. \n• Maryamah, M., Muhammad, M. I., Edric, B. T., Netri, A. R., Mohammad, G., & Indra, K. \nR. (2024). Chatbots in Academia: A Retrieval-Augmented . 2024 16th International \nConference on Knowledge and Smart Technology (KST) (pp. 259-264). Krabi, Thailand: \nIEEE. From PyMuPDF Documentaion: https://pymupdf.readthedocs.io/en/latest/recipes-\ntext.html \n• Ministry of Business, Innovation & Employment. (2014, February 14). New Zealand \nBuilding Code Handbook. From Building Gov NZ: \nhttps://www.building.govt.nz/assets/Uploads/building-code-\ncompliance/handbooks/building-code-handbook/building-code-handbook-3rd-edition-\namendment-13.pdf \n• Ministry of Business, Innovation & Employment. (2016, March 21). Alternative solutions \nfor compliance with the Building Code. From Building Gov NZ: \nhttps://www.building.govt.nz/building-code-compliance/how-the-building-code-\nworks/different-ways-to-comply/alternative-solutions \n• Ministry of Business, Innovation & Employment. (2021, May 28). AS/NZS 3500.1:2021 \nPlumbing and drainage Part 1: Water services. From Building CodeHub Nz: \nhttps://codehub.building.govt.nz/resources/asnzs-3500-12021 \n• Ministry of Business, Innovation & Employment. (2026, January 28). Acceptable \nsolutions and verification methods. From Building Gov NZ:'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 31, 'page_label': '32'}, page_content='https://www.building.govt.nz/building-code-compliance/how-the-building-code-\nworks/different-ways-to-comply/acceptable-solutions-and-verification-methods \n• MongoDB. (n.d.). MongoDB\'s Flexible Schema: Unpacking the "Schemaless Database. \nFrom MongoDB: https://www.mongodb.com/resources/basics/unstructured-\ndata/schemaless \n• OpenAI. (2022, December 16). How to count tokens with Tiktoken. From OpenAI \nDevelopers: \nhttps://developers.openai.com/cookbook/examples/how_to_count_tokens_with_tiktoken \n• OpenAI. (n.d.). GPT-4.1 mini. From OpenAI Platform: \nhttps://platform.openai.com/docs/models/gpt-4.1-mini \n• OpenAI. (n.d.). tiktoken. From GitHub, Inc: https://github.com/openai/tiktoken \n• Pinecone Systems, Inc. (n.d.). Hybrid search. From Pinecone Systems, Inc: \nhttps://docs.pinecone.io/guides/search/hybrid-search \n• Pinecone Systems, Inc. (n.d.). Models: bge-reranker-v2-m3. From Pinecone Systems, \nInc: https://docs.pinecone.io/models/bge-reranker-v2-m3 \n• Pinecone Systems, Inc. (n.d.). Models: pinecone-sparse-english-v0. From Pinecone \nSystems, Inc. \n• PyMuPDF. (n.d.). Text extraction recipes / tutorial. From PyMuPDF Documentation: \nhttps://pymupdf.readthedocs.io/en/latest/recipes-text.html \n• STANDARDS AUSTRALIA. (2021, May). Standards Catalogue - AS/NZS 3500.3:2021. \nFrom STANDARDS AUSTRALIA: https://www.standards.org.au/standards-\ncatalogue/standard-details?designation=as-nzs-3500-3-2021 \n \nAcknowledgements \nChatGPT was used during development to assist with correcting implementation errors and \ndebugging issues encountered in the system. It was also used to support UI styling and layout \nrefinement in the Next.js frontend. Grammarly was used to review and correct grammar and clarity \nin the written report.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 32, 'page_label': '33'}, page_content='Appendices \nAppendix A: Links \nDeployed application: https://foleys-ai-assistance-app-production.up.railway.app/ \nEmail: nirosigaa@mail.com \nPassword: 123456 \nAppendix B: Database Schema \nPostgres Schema \nUsers table \nThis table stores authenticated user information and is used during login, authorization checks, \nand access control. \n• id (UUID) – unique user identifier \n• email (TEXT) – user email address (unique) \n• password_hash (TEXT) – securely hashed password \n• name (TEXT) – user display name \n• role (TEXT) – user role (for example USER or ADMIN) \n• company (TEXT, nullable) – organisation affiliation \n• is_active (BOOLEAN) – account status \n• created_at (TIMESTAMP) – account creation time \n• updated_at (TIMESTAMP) – last update time \n \nConversation analytics table \nThis table records structured usage metrics for each assistant response. It enables analysis of \nsystem performance, cost, and usage patterns. \n• id (UUID) – analytics record identifier \n• user_id (UUID) – reference to users table \n• user_name (TEXT) – user name at time of interaction \n• company (TEXT, nullable) – company name \n• conversation_id (TEXT) – MongoDB conversation reference \n• message_id (TEXT, nullable) – MongoDB message reference \n• model (TEXT) – language model used \n• prompt_tokens (INTEGER) – number of prompt tokens'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 33, 'page_label': '34'}, page_content='• completion_tokens (INTEGER) – number of completion tokens \n• total_tokens (INTEGER) – total tokens used \n• latency_ms (INTEGER) – response latency in milliseconds \n• created_at (TIMESTAMP) – record creation time \n \nFeedback analytics table \nThis table stores structured feedback data for reporting and dashboard visualisation. \n• id (UUID) – feedback record identifier \n• user_id (UUID) – reference to users table \n• user_name (TEXT) – user name \n• conversation_id (TEXT) – conversation reference \n• message_id (TEXT) – message reference \n• rating (TEXT) – feedback rating (positive or negative) \n• category (TEXT) – feedback category \n• feedback_text (TEXT, nullable) – optional user comment \n• created_at (TIMESTAMP) – feedback submission time \n \nMongoDB Schema \nConversations collection \nEach document represents a single chat session. \n• _id (ObjectId) – conversation identifier \n• userId (ObjectId or STRING) – user reference \n• title (STRING) – conversation title \n• summary (STRING, nullable) – optional summary \n• messageCount (INTEGER) – number of messages \n• createdAt (DATETIME) – creation timestamp \n• updatedAt (DATETIME) – last update timestamp \n• deletedAt (DATETIME, nullable) – soft delete marker \n \nMessages collection \nEach document represents a single message within a conversation. \n• _id (ObjectId) – message identifier \n• conversationId (ObjectId or STRING) – conversation reference'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 34, 'page_label': '35'}, page_content='• userId (ObjectId or STRING) – user reference \n• role (STRING) – message role (user or assistant) \n• content (STRING) – message text \n• sequence (INTEGER) – ordering within conversation \n• timestamp (DATETIME) – message time \n \nMessage metadata (embedded document) \nStored only for assistant messages to support evaluation and analytics. \n• model (STRING) – language model used \n• promptTokens (INTEGER, nullable) – prompt token count \n• completionTokens (INTEGER, nullable) – completion token count \n• latencyMs (INTEGER, nullable) – response latency \n• sources (ARRAY) – retrieved source metadata \n \nMessage feedback collection \nStores user feedback linked to individual assistant messages. \n• _id (ObjectId) – feedback identifier \n• messageId (ObjectId or STRING) – message reference \n• conversationId (ObjectId or STRING) – conversation reference \n• userId (ObjectId or STRING) – user reference \n• rating (STRING) – positive or negative \n• comment (STRING, nullable) – optional feedback text \n• categories (ARRAY of STRING) – selected feedback categories \n• submittedAt (DATETIME) – feedback submission time \n• createdAt (DATETIME) – record creation time \n• updatedAt (DATETIME) – last update time \n \nPinecone Chunk record metadata (stored in both dense and sparse indexes) \n• id (STRING) – unique chunk identifier \n• chunk_text (STRING) – extracted text content \n• doc_title (STRING) – document title \n• filename (STRING) – source PDF filename'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 35, 'page_label': '36'}, page_content='• file_link (STRING) – public S3 URL \n• page_number (INTEGER) – source page number \n• standard_type (STRING) – standard category (e.g. AS/NZS, NZBC) \n• edition_year (INTEGER) – document edition year \n• currency_status (STRING) – current or superseded \nAppendix C: User Interface Design \n \n \nFigure 4 - Login page \n \nFigure 5 -  Chat page'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 36, 'page_label': '37'}, page_content='Figure 6 - Chat response \n \n \n \n \nFigure 7 - PDF Navigation'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 37, 'page_label': '38'}, page_content='Figure 8 - Admin dashboard(Analytics) \n \n \nFigure 9 - Admin dashboard(Feedback List)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 38, 'page_label': '39'}, page_content='Figure 10 – Chat detail page'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 39, 'page_label': '40'}, page_content='Appendix D: AWS S3 Bucket \n \n \nFigure 11 - S3 Bucket for PDF Storage \n \n \nFigure 12 - S3 Bucket Public Policy'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 40, 'page_label': '41'}, page_content='Appendix E: Postgres Table \n \n \nFigure 13 - conversation_analytics postgres table \n \n \nFigure 14 - feedback_analytics postgres table'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 41, 'page_label': '42'}, page_content='Figure 15 - users postgres table \n \nAppendix F: MongoDB Collection \n \nFigure 16 - conversations mongo collection'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 42, 'page_label': '43'}, page_content='Figure 17 - messages mongo collection \n \nFigure 18 - message_feedback mongo collection'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 43, 'page_label': '44'}, page_content='Appendix G: LLM Prompt \n \n \nFigure 19 - LLM System Prompt \n \n \nFigure 20 - LLM User Prompt')]

# %%
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
documents=text_splitter.split_documents(pdf_docs)
documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 0, 'page_label': '1'}, page_content='Plumbing AI Compliance Assistant: A\n Retrieval- Augmented Generation \nProof of Concept \n \n \n \n \n \nUniversity University of Canterbury \nDegree Master of Applied Data Science \nCourse DATA605-25X – Industry Based Research Project \nIndustry Foleys \nPrimary Supervisor Phil Davies \nSecondary Supervisor Yiwen Lyu \nIndustry Supervisors Gwen Slote \nGroup members Nirosigaa Subendran (98402523) \nMahendher Thatikonda (16485324)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 1, 'page_label': '2'}, page_content='Executive Summary \nFoleys staff regularly need quick, reliable answers from New Zealand plumbing and building \ncompliance documents while planning work, quoting, ordering materials, or resolving on -site \nquestions. In practice, those answers are buried across multiple standard s and Building Code \nguidance, and the work often depends on time -consuming manual searches and informal \nknowledge held by senior staff. This project developed a proof -of-concept Compliance AI \nAssistant to reduce search time while preserving accountability through evidence -based \nresponses.  \n \nThe system was built using a Retrieval-Augmented Generation (RAG) approach in which official \ndocuments act as the sole source of truth. A fixed corpus of 27 compliance documents was \nestablished and processed into chunked, metadata-rich records with page-level traceability. The \nfinal ingestion workflow uses fast page -based extraction, conservative text normalisation, and'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 1, 'page_label': '2'}, page_content='established and processed into chunked, metadata-rich records with page-level traceability. The \nfinal ingestion workflow uses fast page -based extraction, conservative text normalisation, and \ntoken-aware chunking. Each chunk is indexed in Pinecone using two complementary indexes: a \ndense semantic index and a sparse lexical index.  At query time, the system retrieves 20 \ncandidates from each index, merges and deduplicates results, then applies Pinecone reranking \nto select the top five evidence passages for answer generation using gpt-4.1-mini.  \n \nEvaluation using representative questions provided by Foleys showed stable retrieval behavior \nand generally strong answer quality when the relevant clause or table was retrieved. The assistant \nproduced structured outputs that separate AS/NZS requirements f rom New Zealand Building \nCode (NZBC) material and includes exact evidence quotes with page -level S3 links in the form,'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 1, 'page_label': '2'}, page_content='produced structured outputs that separate AS/NZS requirements f rom New Zealand Building \nCode (NZBC) material and includes exact evidence quotes with page -level S3 links in the form, \nenabling direct verification. When evidence was insufficient, the system stated limitations rather \nthan guessing. End -to-end latency was acceptable for proof -of-concept, with generation time \ncontributing most variability. Overall, the prototype demonstrates that an evidence-grounded RAG \nassistant can act as a practical navigation layer over compliance documents, while highlighting \nthe need for continued work on retrieval coverage, ambiguity handling, and larger-scale validation.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='Table of Contents \nExecutive Summary ................................ ................................ ................................ ................... 2 \nTable of Contents ................................ ................................ ................................ ....................... 3 \nList of Figures ................................ ................................ ................................ ............................ 5 \n1. Introduction ................................ ................................ ................................ ............................ 6 \n2. Problem Statement ................................ ................................ ................................ ................ 6 \n3. Project Aims and Scope ................................ ................................ ................................ ......... 7'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='3. Project Aims and Scope ................................ ................................ ................................ ......... 7 \n3.1 Aims ................................ ................................ ................................ ................................ . 7 \n4. Background and Standards Context ................................ ................................ ....................... 8 \n4.1 Performance-based regulation and compliance pathways ................................ ................ 8 \n4.2 Standards versions and practical interpretation ................................ ................................  8 \n5. Method ................................ ................................ ................................ ................................ ... 9 \n5.1 Overall approach ................................ ................................ ................................ .............. 9'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='5.1 Overall approach ................................ ................................ ................................ .............. 9 \n5.2 System Architecture Overview ................................ ................................ .......................... 9 \n5.3 Database Design and Data Storage ................................ ................................ ................10 \n5.3.1 PostgreSQL (Relational Storage) ................................ ................................ ..............10 \n5.3.2 MongoDB Atlas (Document Storage) ................................ ................................ ........11 \n5.3.3 Pinecone (Vector Database for Retrieval) ................................ ................................ .11 \n5.4 Document Ingestion Pipeline ................................ ................................ ...........................11 \n5.4.1 Document Upload and Source Management ................................ .............................11'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='5.4.1 Document Upload and Source Management ................................ .............................11 \n5.4.2 PDF Text Extraction ................................ ................................ ................................ ..11 \n5.4.3 Text Cleaning and Normalisation ................................ ................................ ..............12 \n5.4.4 Metadata Construction and Version Context ................................ .............................12 \n5.4.4 Token-Aware Chunking ................................ ................................ .............................12 \n5.4.5 Vector Indexing and Upload ................................ ................................ ......................13 \n5.4.6 Upload Process and Metadata Consistency ................................ .............................. 14 \n5.4.6 Evidence Preservation and Traceability ................................ ................................ ....14'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 2, 'page_label': '3'}, page_content='5.4.6 Evidence Preservation and Traceability ................................ ................................ ....14 \n5.5 RAG Pipeline Implementation ................................ ................................ ..........................15 \n5.5.1 Hybrid Retrieval Strategy ................................ ................................ ..........................15 \n5.5.2 Reranking for Relevance ................................ ................................ ...........................16 \n5.5.3 Context Construction for Generation ................................ ................................ .........16 \n5.5.4 Answer Generation and Citation ................................ ................................ ................17 \n5.5.5 Design Rationale ................................ ................................ ................................ .......17'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='5.6 User Interaction Flow ................................ ................................ ................................ .......18 \n5.6.1 User Authentication and Session Management ................................ .........................18 \n5.6.2 Real-Time Chat Communication ................................ ................................ ...............18 \n5.6.3 Query Processing and RAG Invocation ................................ ................................ .....19 \n5.6.4 Answer Generation and Streaming Response ................................ ...........................19 \n5.6.5 Citation Handling and Source Navigation ................................ ................................ ..19 \n5.6.6 Conversation and Message Persistence ................................ ................................ ...20 \n5.6.7 Feedback Collection and Storage ................................ ................................ .............20'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='5.6.7 Feedback Collection and Storage ................................ ................................ .............20 \n6. Data ................................ ................................ ................................ ................................ ......20 \n6.1 Data Sources and Composition ................................ ................................ .......................20 \n6.2 Document Diversity ................................ ................................ ................................ .........21 \n6.3 Data Summary Visualisation ................................ ................................ ............................21 \n6.4 Relevance to the RAG Approach ................................ ................................ .....................22 \n7. Results ................................ ................................ ................................ ................................ ..23'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='7. Results ................................ ................................ ................................ ................................ ..23 \n7.1 Question Coverage and Retrieval Performance ................................ ............................... 23 \n7.2 Answer Quality and Evidence Grounding................................ ................................ .........24 \n7.3 Handling of Ambiguity and Missing Information ................................ ............................... 25 \n7.4 System Responsiveness ................................ ................................ ................................ .27 \n8. Outcomes ................................ ................................ ................................ .............................27 \n8.1 Primary Project Outcomes ................................ ................................ ............................... 27'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='8.1 Primary Project Outcomes ................................ ................................ ............................... 27 \n8.2 Technical Outcomes ................................ ................................ ................................ ........28 \n8.3 Evaluation Outcomes................................ ................................ ................................ .......28 \n8.4 Practical Outcomes for Foleys ................................ ................................ .........................29 \n8.5 Limitations and Scope of Outcomes ................................ ................................ ................29 \n9. Conclusion ................................ ................................ ................................ ............................30 \n10. Future Work ................................ ................................ ................................ ........................30'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='10. Future Work ................................ ................................ ................................ ........................30 \nReferences ................................ ................................ ................................ ............................... 31 \nAcknowledgements ................................ ................................ ................................ ...................32 \nAppendices ................................ ................................ ................................ ............................... 33 \nAppendix A: Links ................................ ................................ ................................ ..................33 \nAppendix B: Database Schema ................................ ................................ .............................33 \nPostgres Schema ................................ ................................ ................................ ...............33'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 3, 'page_label': '4'}, page_content='Postgres Schema ................................ ................................ ................................ ...............33 \nMongoDB Schema ................................ ................................ ................................ .............34'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='Pinecone Chunk record metadata (stored in both dense and sparse indexes) ...................35 \nAppendix C: User Interface Design ................................ ................................ ........................36 \nAppendix D: AWS S3 Bucket ................................ ................................ ................................ .40 \nAppendix E: Postgres Table ................................ ................................ ................................ ..41 \nAppendix F: MongoDB Collection ................................ ................................ ..........................42 \nAppendix G: LLM Prompt ................................ ................................ ................................ ......44 \n \nList of Figures \nFigure 1- System Architecture ................................ ................................ ................................ ...10'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='List of Figures \nFigure 1- System Architecture ................................ ................................ ................................ ...10 \nFigure 2 - User Query Flow ................................ ................................ ................................ .......18 \nFigure 3 - Data Summary ................................ ................................ ................................ ..........22 \nFigure 4 - Login page ................................ ................................ ................................ ................36 \nFigure 5 -  Chat page ................................ ................................ ................................ ................36 \nFigure 6 - Chat response ................................ ................................ ................................ ..........37 \nFigure 7 - PDF Navigation ................................ ................................ ................................ .........37'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='Figure 7 - PDF Navigation ................................ ................................ ................................ .........37 \nFigure 8 - Admin dashboard(Analytics) ................................ ................................ .....................38 \nFigure 9 - Admin dashboard(Feedback List) ................................ ................................ .............38 \nFigure 10 – Chat detail page ................................ ................................ ................................ .....39 \nFigure 11 - S3 Bucket for PDF Storage ................................ ................................ .....................40 \nFigure 12 - S3 Bucket Public Policy ................................ ................................ ..........................40 \nFigure 13 - conversation_analytics postgres table ................................ ................................ .....41'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='Figure 13 - conversation_analytics postgres table ................................ ................................ .....41 \nFigure 14 - feedback_analytics postgres table ................................ ................................ ..........41 \nFigure 15 - users postgres table ................................ ................................ ................................ 42 \nFigure 16 - conversations mongo collection ................................ ................................ ..............42 \nFigure 17 - messages mongo collection ................................ ................................ ....................43 \nFigure 18 - message_feedback mongo collection ................................ ................................ .....43 \nFigure 19 - LLM System Prompt ................................ ................................ ............................... 44'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 4, 'page_label': '5'}, page_content='Figure 19 - LLM System Prompt ................................ ................................ ............................... 44 \nFigure 20 - LLM User Prompt ................................ ................................ ................................ ....44'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 5, 'page_label': '6'}, page_content='1. Introduction \nCompliance work in the building and plumbing industry is not only technical, it is also time \nsensitive. In Foleys’ context, staff may need to confirm requirements while planning jobs, quoting, \nordering materials, or deciding what is acceptable on-site. These questions are rarely phrased in \nthe same way standards are written. People ask in everyday language, they shorten terms, they \nuse trade shorthand, and they often start with a partial idea rather than a clean specification. \n \nAt the same time, New Zealand building regulations and supporting compliance documents are \ncomplex, and they are designed to be interpreted within a compliance framework  (Ministry of \nBusiness, Innovation & Employment, 2014). Building regulations are performance-based, so they \ndescribe what must be achieved rather than prescribing one exact solution. In practice, people \nrely on compliance pathways like Acceptable Solutions and Verification Methods, or they propose'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 5, 'page_label': '6'}, page_content='describe what must be achieved rather than prescribing one exact solution. In practice, people \nrely on compliance pathways like Acceptable Solutions and Verification Methods, or they propose \nAlternative Solutions with supporting evidence. For plumbing and drainage, the AS/NZS 3500 \nstandards form a key pathway for “how to comply” under commonly used Acceptable Solutions \n(Ministry of Business, Innovation & Employment, 2026). That combination is powerful, but it also \ncreates an information problem: the relevant answer is often present, but it is buried inside a large \nset of documents, and the user needs to find it quickly and interpret it correctly. \n \nThis project sets out to design a Retrieval -Augmented Generation assistant that makes \ncompliance information easier to access while preserving accountability. The goal was not to \nreplace professional judgement or regulatory responsibility. It was to reduce time spent searching,'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 5, 'page_label': '6'}, page_content='compliance information easier to access while preserving accountability. The goal was not to \nreplace professional judgement or regulatory responsibility. It was to reduce time spent searching, \nimprove consistency in referencing authoritative documents, and create a more transparent way \nto answer common questions, including links and citations so users can verify the source. \n2. Problem Statement \nFrom discussions with the project context and typical operational realities, the core problem can \nbe summarised as follows: \n• Manual searching is slow and disruptive. Locating answers within technical standards \noften involves repeated keyword searches, extensive scrolling, and cross -referencing \nacross multiple PDF documents. \n• Regulations are hard to navigate. Standards and Acceptable Solutions are drafted for \naccuracy, not for quick search by time-pressed staff.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 6, 'page_label': '7'}, page_content='• Compliance risk carries real cost. Misinterpretation or overlooking a requirement can \ncause rework, delays, failed inspections, penalties, and serious long -term reputational \ndamage. \n• Knowledge can be concentrated in senior staff . When answers depend on a small \ngroup of experienced people, it creates a bottleneck and increases the risk of inconsistent \nadvice when those staff are unavailable. \n• Version changes add uncertainty . Differences between editions (for example, 2022 \nversus 2025 editions) can create confusion, especially when newer editions are not yet \nreferenced by legislation but may still be used as Alternative Solutions. \n \nThis is fundamentally a data and decision -support problem: how can we retrieve the right \nevidence from authoritative documents quickly, then present it in a way that users trust and can \naudit. \n3. Project Aims and Scope \n3.1 Aims \nThe project aimed to build and test a proof-of-concept that can:'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 6, 'page_label': '7'}, page_content='audit. \n3. Project Aims and Scope \n3.1 Aims \nThe project aimed to build and test a proof-of-concept that can: \n1. Standards Retrieval : Allow users to ask natural language questions and receive \naccurate, up-to-date answers grounded in official compliance documents. \n2. Contextual Understanding: Handle paraphrasing and variations in how questions are \nasked, and request clarification when queries are ambiguous. \n3. Document Navigation : Provide citations and deep links to relevant sections, and \nsummarise long sections into concise, actionable points. \n4. Multi-format Support : Return text answers and optionally provide downloadable \nreferences (such as PDF links or supporting diagrams, when available). \n5. Updated Standards Awareness: Summarise changes between document versions and \nnote the compliance status (for example, when an edition is not yet referenced by the \nBuilding Code but could be used as an Alternative Solution).'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 6, 'page_label': '7'}, page_content='note the compliance status (for example, when an edition is not yet referenced by the \nBuilding Code but could be used as an Alternative Solution). \n6. Feedback Loop: Enable users to rate responses or flag inaccuracies, supporting iterative \nimprovement.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 7, 'page_label': '8'}, page_content='4. Background and Standards Context \n4.1 Performance-based regulation and compliance pathways \nNew Zealand building regulations operate on a performance basis. This means the law describes \noutcomes that must be achieved (for example, water systems must be safe and hygienic), rather \nthan prescribing a single method. Compliance pathways support how those outcomes are shown \nin practice: \n• Acceptable Solutions: Prescriptive paths that, if followed, are accepted as compliant. \n• Verification Methods: Methods based on testing or calculations that are used to show \ncompliance. \n• Alternative Solutions: Different approaches that can be put forward and justified using \nsupporting evidence. \nIn day-to-day plumbing practice, AS/NZS standards are relied on as a practical guide for applying \nrequirements in real situations. The AS/NZS 3500 series is commonly regarded as the primary \nreference for plumbing and drainage work (Ministry of Business, Innovation & Employment, 2021)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 7, 'page_label': '8'}, page_content='requirements in real situations. The AS/NZS 3500 series is commonly regarded as the primary \nreference for plumbing and drainage work (Ministry of Business, Innovation & Employment, 2021) \n. Alongside this, Building Code linkage documents and Acceptable Solutions, including those \nrelated to the G12 Water Supplies area, are regularly used within the industry and help bring \nstructure to what would otherwise be a wide and technically demanding set of standards (Ministry \nof Business, Innovation & Employment, 2026). \n4.2 Standards versions and practical interpretation \nA practical issue arises from the fact that multiple editions of the same standard can exist, while \nonly certain versions are referenced within Acceptable Solutions at any given time  (Ministry of \nBusiness, Innovation & Employment, 2026). Within the context of this project: \n• The 2021/2022 editions were treated as the current Acceptable Solutions reference point \n(Ministry of Business, Innovation & Employment, 2014).'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 7, 'page_label': '8'}, page_content='• The 2021/2022 editions were treated as the current Acceptable Solutions reference point \n(Ministry of Business, Innovation & Employment, 2014). \n• 2025 editions were noted as not yet referenced by legislation but could still be used as \nAlternative Solutions. \n• Older editions (for example 2018 versions in some cases) were considered superseded \nand not recommended as the main compliance reference. \nThis matters for a RAG assistant bec ause the system must not only retrieve text, it must also \ncommunicate the status and context of that text.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 8, 'page_label': '9'}, page_content='5. Method \n5.1 Overall approach \nThis project followed a data -centric approach to the development of a proof -of-concept \nCompliance AI Assistant for New Zealand building and plumbing standards. Rather than aiming \nfor open -ended conversation, the emphasis was placed on supporting compliance -related \ndecision making by ensuring accurate information retrieval and the clear, transparent presentation \nof authoritative sources. \n \nThe system was designed using a RAG paradigm, where official standards documents form the \nsole source of truth. Large Language Models (LLM) are used only to synthesise and summarise \nretrieved content, rather than to generate answers independently. This ensures that responses \nremain grounded in verifiable evidence. \n \nThe work followed a three -stage process. The process started by defining a fixed collection of \nofficial compliance documents and converting them into a searchable format, while still'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 8, 'page_label': '9'}, page_content='The work followed a three -stage process. The process started by defining a fixed collection of \nofficial compliance documents and converting them into a searchable format, while still \nmaintaining page-level traceability. The next stage then focused on developing a hybrid retrieval \nstrategy that combined semantic search with lexical matching, enabling the system to respond to \nboth everyday language questions and more specialised technical terminology. In the final stage, \na controlled generation layer was used  to generate structured responses, with each answer \nclearly supported by citations that pointed back to the original source documents. \n \nOverall, this approach mirrors the way compliance tasks are carried out in real settings, where \nclarity, accuracy, and traceability matter, and it tre ats the system as a tool to support decision \nmaking rather than something intended to replace professional judgement. \n5.2 System Architecture Overview'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 8, 'page_label': '9'}, page_content='making rather than something intended to replace professional judgement. \n5.2 System Architecture Overview \nThe system is built using a multi -tier architecture that separates the user interface, application \nlogic, and data storage. A Next.js frontend is used to deliver the chat interface and admin \ndashboard, while a FastAPI backend runs the RAG pipeline through a combination of \nWebSockets and REST Application Programming Interface (API) . Information retrieval is \nmanaged through Pinecone hybrid search, using both a dense index and a sparse index with \nreranking, and OpenAI gpt-4.1-mini is used to generate the final responses with evidence-based'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 9, 'page_label': '10'}, page_content='citations. PostgreSQL is used to store user data and structured analytics, while MongoDB Atlas \nholds conversation histories, messages, and feedback. PDF documents are uploaded to AWS \nS3, and citations are linked to the exact source pages. \n \nFigure 1- System Architecture \n5.3 Database Design and Data Storage \nThe system uses a hybrid data storage approach to accommodate both structured operational \ndata and more flexible conversational data. Relational  data storage is applied in areas where \nconsistency, data integrity, and analytical querying are important, while document-based storage \nis used to manage conversational context and message -level metadata. A separate vector \ndatabase is employed to enable effective retrieval across the compliance document corpus. \n5.3.1 PostgreSQL (Relational Storage) \nPostgreSQL is used to store user accounts and structured analytics data. This database \nunderpins core system functions such as authentication, role -based access control,'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 9, 'page_label': '10'}, page_content='PostgreSQL is used to store user accounts and structured analytics data. This database \nunderpins core system functions such as authentication, role -based access control, \nadministrative reporting, and overall system monitoring. The data held in PostgreSQL follow a \nrelatively stable structure and are well suited to relational constraints and indexing, which supports \nconsistency and efficient querying. Postgres schema see in appendix.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 10, 'page_label': '11'}, page_content='5.3.2 MongoDB Atlas (Document Storage) \nMongoDB Atlas is used to store conversational data, which is naturally hierarchical and benefits \nfrom a flexible schema  (MongoDB, n.d.). This database captures the full chat history, message \nsequencing, and detailed metadata associated with each assistant response. MongoDB schema \nsee in appendix. \n5.3.3 Pinecone (Vector Database for Retrieval) \nPinecone is used to store and retrieve document chunks for the retrieval -augmented generation \npipeline. Two separate indexes are maintained to enable hybrid retrieval (Pinecone Systems, Inc, \nn.d.). Pinecone metadata schema see in appendix. \n5.4 Document Ingestion Pipeline \nThe document ingestion pipeline transforms compliance PDFs into a structured and searchable \nrepresentation that supports retrieval -augmented generation while preserving traceability to \noriginal source documents. The pipeline was designed with a strong emph asis on regulatory'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 10, 'page_label': '11'}, page_content='representation that supports retrieval -augmented generation while preserving traceability to \noriginal source documents. The pipeline was designed with a strong emph asis on regulatory \ntransparency, reproducibility, and alignment with LLM  constraints. \n5.4.1 Document Upload and Source Management \nAll compliance documents are uploaded manually to an AWS S3 bucket and handled as \nimmutable source artefacts. This setup ensures that the system works with a fixed and auditable \nset of documents, which is particularly important in a compliance setting. AWS  S3 was chosen \nbecause it offers stable, publicly accessible URLs that can be shared directly with end users. \n \nRather than generating page -specific links during ingestion, the pipeline stores the base S3 \ndocument link together with the page number as metadata. During answer generation, these \nvalues are combined to produce citations in the format <s3-link>#page=<page_number>,'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 10, 'page_label': '11'}, page_content='document link together with the page number as metadata. During answer generation, these \nvalues are combined to produce citations in the format <s3-link>#page=<page_number>, \nallowing users to open the exact supporting page in the original PDF (Adobe, 2007). \n5.4.2 PDF Text Extraction \nText extraction is performed at the page level to ensure that all retrieved evidence can be traced \nback to an exact location in the source document. Early versions of the pipeline used pdfplumber \nbecause of its accuracy on complex PDF layouts. When processing large standards documents, \nthis approach proved to be computationally slow and unsuitable for repeated ingestion runs.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 11, 'page_label': '12'}, page_content='The final implementation uses PyMuPDF, which provides significantly faster page -level text \nextraction while still preserving page boundaries (PyMuPDF, n.d.). Each page is processed one \nat a time, with the extracted text explicitly linked to its corresponding page number. Maintaining \nthis link is important because the page numbers are later shown directly to users as part of the \ncitation process. \n5.4.3 Text Cleaning and Normalisation \nExtracted text is lightly cleaned to reduce noise introduced by PDF formatting. This step includes \nnormalising whitespace, collapsing excessive line breaks, and removing layout artefacts that \ncould interfere with tokenisation or embedding. Cleaning is inte ntionally conservative to avoid \naltering regulatory wording, as even minor textual changes could affect compliance interpretation. \n \nThe purpose of this step is to improve consistency across documents with different layouts rather \nthan to rewrite or summarise content.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 11, 'page_label': '12'}, page_content='The purpose of this step is to improve consistency across documents with different layouts rather \nthan to rewrite or summarise content. \n5.4.4 Metadata Construction and Version Context \nEach document is assigned structured metadata before chunking. Metadata fields include \ndocument title, filename, standard type, edition year, and currency status. These attributes are \ninferred based on filename conventions and recognised naming patterns commonly used in New \nZealand compliance documents. \n \nWhen multiple editions of a standard are available, the metadata records whether a document \naligns with a currently referenced Building Code edition or represents a newer version that may \nonly be applicable as an Alternative Solution. Storing this information explicitly provides important \nregulatory context during retrieval and reduces the risk of users misinterpreting answers. \n5.4.4 Token-Aware Chunking'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 11, 'page_label': '12'}, page_content='regulatory context during retrieval and reduces the risk of users misinterpreting answers. \n5.4.4 Token-Aware Chunking \nChunking is carried out using a token-aware strategy that is aligned with the tokenisation scheme \nof the OpenAI language model used for answer generation. The system applies the cl100k_base \ntoken encoding (OpenAI, n.d.), which is consistent with the token units used by OpenAI models \nwhen determining context length and token limits  (OpenAI, 2022). As a result, the chunk sizes \ndefined during ingestion directly reflect how the language model later interprets and processes \ntext at inference time.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 12, 'page_label': '13'}, page_content='A token-based approach was chosen instead of character-based chunking to avoid mismatches \nbetween preprocessing and generation. Character counts are a poor proxy for actual model \ncontext usage, particularly in regulatory documents that include symbols, tab les, and technical \nformatting. By working in token space, the pipeline is able to keep each chunk within a predictable \nand safe portion of the model’s effective context window (Maryamah, et al., 2024). \n \nAs part of the ingestion stage, chunks are created to be roughly 1,740 tokens in length, with a \n205-token overlap between neighboring chunks. These parameters were set to manage the trade-\noff between retrieving enough relevant information and keeping proce ssing costs reasonable. \nSetting the chunk size to 1,740 tokens allows related regulatory content, such as full clauses or \nexplanations linked to tables, to remain grouped together without creating chunks that are too'),
# ...
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 30, 'page_label': '31'}, page_content='Generation-Based LLMs for Medical Chatbot Applications. Machine Learning & \nKnowledge Extraction, 2356-2356. \n• Maryamah, M., Muhammad, M. I., Edric, B. T., Netri, A. R., Mohammad, G., & Indra, K. \nR. (2024). Chatbots in Academia: A Retrieval-Augmented . 2024 16th International \nConference on Knowledge and Smart Technology (KST) (pp. 259-264). Krabi, Thailand: \nIEEE. From PyMuPDF Documentaion: https://pymupdf.readthedocs.io/en/latest/recipes-\ntext.html \n• Ministry of Business, Innovation & Employment. (2014, February 14). New Zealand \nBuilding Code Handbook. From Building Gov NZ: \nhttps://www.building.govt.nz/assets/Uploads/building-code-\ncompliance/handbooks/building-code-handbook/building-code-handbook-3rd-edition-\namendment-13.pdf \n• Ministry of Business, Innovation & Employment. (2016, March 21). Alternative solutions \nfor compliance with the Building Code. From Building Gov NZ: \nhttps://www.building.govt.nz/building-code-compliance/how-the-building-code-'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 30, 'page_label': '31'}, page_content='for compliance with the Building Code. From Building Gov NZ: \nhttps://www.building.govt.nz/building-code-compliance/how-the-building-code-\nworks/different-ways-to-comply/alternative-solutions \n• Ministry of Business, Innovation & Employment. (2021, May 28). AS/NZS 3500.1:2021 \nPlumbing and drainage Part 1: Water services. From Building CodeHub Nz: \nhttps://codehub.building.govt.nz/resources/asnzs-3500-12021 \n• Ministry of Business, Innovation & Employment. (2026, January 28). Acceptable \nsolutions and verification methods. From Building Gov NZ:'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 31, 'page_label': '32'}, page_content='https://www.building.govt.nz/building-code-compliance/how-the-building-code-\nworks/different-ways-to-comply/acceptable-solutions-and-verification-methods \n• MongoDB. (n.d.). MongoDB\'s Flexible Schema: Unpacking the "Schemaless Database. \nFrom MongoDB: https://www.mongodb.com/resources/basics/unstructured-\ndata/schemaless \n• OpenAI. (2022, December 16). How to count tokens with Tiktoken. From OpenAI \nDevelopers: \nhttps://developers.openai.com/cookbook/examples/how_to_count_tokens_with_tiktoken \n• OpenAI. (n.d.). GPT-4.1 mini. From OpenAI Platform: \nhttps://platform.openai.com/docs/models/gpt-4.1-mini \n• OpenAI. (n.d.). tiktoken. From GitHub, Inc: https://github.com/openai/tiktoken \n• Pinecone Systems, Inc. (n.d.). Hybrid search. From Pinecone Systems, Inc: \nhttps://docs.pinecone.io/guides/search/hybrid-search \n• Pinecone Systems, Inc. (n.d.). Models: bge-reranker-v2-m3. From Pinecone Systems, \nInc: https://docs.pinecone.io/models/bge-reranker-v2-m3'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 31, 'page_label': '32'}, page_content='https://docs.pinecone.io/guides/search/hybrid-search \n• Pinecone Systems, Inc. (n.d.). Models: bge-reranker-v2-m3. From Pinecone Systems, \nInc: https://docs.pinecone.io/models/bge-reranker-v2-m3 \n• Pinecone Systems, Inc. (n.d.). Models: pinecone-sparse-english-v0. From Pinecone \nSystems, Inc. \n• PyMuPDF. (n.d.). Text extraction recipes / tutorial. From PyMuPDF Documentation: \nhttps://pymupdf.readthedocs.io/en/latest/recipes-text.html \n• STANDARDS AUSTRALIA. (2021, May). Standards Catalogue - AS/NZS 3500.3:2021. \nFrom STANDARDS AUSTRALIA: https://www.standards.org.au/standards-\ncatalogue/standard-details?designation=as-nzs-3500-3-2021 \n \nAcknowledgements \nChatGPT was used during development to assist with correcting implementation errors and \ndebugging issues encountered in the system. It was also used to support UI styling and layout \nrefinement in the Next.js frontend. Grammarly was used to review and correct grammar and clarity \nin the written report.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 32, 'page_label': '33'}, page_content='Appendices \nAppendix A: Links \nDeployed application: https://foleys-ai-assistance-app-production.up.railway.app/ \nEmail: nirosigaa@mail.com \nPassword: 123456 \nAppendix B: Database Schema \nPostgres Schema \nUsers table \nThis table stores authenticated user information and is used during login, authorization checks, \nand access control. \n• id (UUID) – unique user identifier \n• email (TEXT) – user email address (unique) \n• password_hash (TEXT) – securely hashed password \n• name (TEXT) – user display name \n• role (TEXT) – user role (for example USER or ADMIN) \n• company (TEXT, nullable) – organisation affiliation \n• is_active (BOOLEAN) – account status \n• created_at (TIMESTAMP) – account creation time \n• updated_at (TIMESTAMP) – last update time \n \nConversation analytics table \nThis table records structured usage metrics for each assistant response. It enables analysis of \nsystem performance, cost, and usage patterns. \n• id (UUID) – analytics record identifier'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 32, 'page_label': '33'}, page_content='This table records structured usage metrics for each assistant response. It enables analysis of \nsystem performance, cost, and usage patterns. \n• id (UUID) – analytics record identifier \n• user_id (UUID) – reference to users table \n• user_name (TEXT) – user name at time of interaction \n• company (TEXT, nullable) – company name \n• conversation_id (TEXT) – MongoDB conversation reference \n• message_id (TEXT, nullable) – MongoDB message reference \n• model (TEXT) – language model used \n• prompt_tokens (INTEGER) – number of prompt tokens'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 33, 'page_label': '34'}, page_content='• completion_tokens (INTEGER) – number of completion tokens \n• total_tokens (INTEGER) – total tokens used \n• latency_ms (INTEGER) – response latency in milliseconds \n• created_at (TIMESTAMP) – record creation time \n \nFeedback analytics table \nThis table stores structured feedback data for reporting and dashboard visualisation. \n• id (UUID) – feedback record identifier \n• user_id (UUID) – reference to users table \n• user_name (TEXT) – user name \n• conversation_id (TEXT) – conversation reference \n• message_id (TEXT) – message reference \n• rating (TEXT) – feedback rating (positive or negative) \n• category (TEXT) – feedback category \n• feedback_text (TEXT, nullable) – optional user comment \n• created_at (TIMESTAMP) – feedback submission time \n \nMongoDB Schema \nConversations collection \nEach document represents a single chat session. \n• _id (ObjectId) – conversation identifier \n• userId (ObjectId or STRING) – user reference \n• title (STRING) – conversation title'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 33, 'page_label': '34'}, page_content='Each document represents a single chat session. \n• _id (ObjectId) – conversation identifier \n• userId (ObjectId or STRING) – user reference \n• title (STRING) – conversation title \n• summary (STRING, nullable) – optional summary \n• messageCount (INTEGER) – number of messages \n• createdAt (DATETIME) – creation timestamp \n• updatedAt (DATETIME) – last update timestamp \n• deletedAt (DATETIME, nullable) – soft delete marker \n \nMessages collection \nEach document represents a single message within a conversation. \n• _id (ObjectId) – message identifier \n• conversationId (ObjectId or STRING) – conversation reference'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 34, 'page_label': '35'}, page_content='• userId (ObjectId or STRING) – user reference \n• role (STRING) – message role (user or assistant) \n• content (STRING) – message text \n• sequence (INTEGER) – ordering within conversation \n• timestamp (DATETIME) – message time \n \nMessage metadata (embedded document) \nStored only for assistant messages to support evaluation and analytics. \n• model (STRING) – language model used \n• promptTokens (INTEGER, nullable) – prompt token count \n• completionTokens (INTEGER, nullable) – completion token count \n• latencyMs (INTEGER, nullable) – response latency \n• sources (ARRAY) – retrieved source metadata \n \nMessage feedback collection \nStores user feedback linked to individual assistant messages. \n• _id (ObjectId) – feedback identifier \n• messageId (ObjectId or STRING) – message reference \n• conversationId (ObjectId or STRING) – conversation reference \n• userId (ObjectId or STRING) – user reference \n• rating (STRING) – positive or negative \n• comment (STRING, nullable) – optional feedback text'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 34, 'page_label': '35'}, page_content='• userId (ObjectId or STRING) – user reference \n• rating (STRING) – positive or negative \n• comment (STRING, nullable) – optional feedback text \n• categories (ARRAY of STRING) – selected feedback categories \n• submittedAt (DATETIME) – feedback submission time \n• createdAt (DATETIME) – record creation time \n• updatedAt (DATETIME) – last update time \n \nPinecone Chunk record metadata (stored in both dense and sparse indexes) \n• id (STRING) – unique chunk identifier \n• chunk_text (STRING) – extracted text content \n• doc_title (STRING) – document title \n• filename (STRING) – source PDF filename'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 35, 'page_label': '36'}, page_content='• file_link (STRING) – public S3 URL \n• page_number (INTEGER) – source page number \n• standard_type (STRING) – standard category (e.g. AS/NZS, NZBC) \n• edition_year (INTEGER) – document edition year \n• currency_status (STRING) – current or superseded \nAppendix C: User Interface Design \n \n \nFigure 4 - Login page \n \nFigure 5 -  Chat page'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 36, 'page_label': '37'}, page_content='Figure 6 - Chat response \n \n \n \n \nFigure 7 - PDF Navigation'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 37, 'page_label': '38'}, page_content='Figure 8 - Admin dashboard(Analytics) \n \n \nFigure 9 - Admin dashboard(Feedback List)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 38, 'page_label': '39'}, page_content='Figure 10 – Chat detail page'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 39, 'page_label': '40'}, page_content='Appendix D: AWS S3 Bucket \n \n \nFigure 11 - S3 Bucket for PDF Storage \n \n \nFigure 12 - S3 Bucket Public Policy'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 40, 'page_label': '41'}, page_content='Appendix E: Postgres Table \n \n \nFigure 13 - conversation_analytics postgres table \n \n \nFigure 14 - feedback_analytics postgres table'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 41, 'page_label': '42'}, page_content='Figure 15 - users postgres table \n \nAppendix F: MongoDB Collection \n \nFigure 16 - conversations mongo collection'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 42, 'page_label': '43'}, page_content='Figure 17 - messages mongo collection \n \nFigure 18 - message_feedback mongo collection'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2026-02-05T10:43:09+13:00', 'author': 'Nirosigaa Subendran', 'moddate': '2026-02-05T10:43:09+13:00', 'source': 'DATA605_Foleys3_final_report (3).pdf', 'total_pages': 44, 'page': 43, 'page_label': '44'}, page_content='Appendix G: LLM Prompt \n \n \nFigure 19 - LLM System Prompt \n \n \nFigure 20 - LLM User Prompt')]

# %%
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
db=Chroma.from_documents(documents[:20],OpenAIEmbeddings(),collection_name="PDF-CHATBOT-TEST")

# %%
query="Who prepared this report?"
result=db.similarity_search(query)
result[1].page_content
# Out:
# 'produced structured outputs that separate AS/NZS requirements f rom New Zealand Building \nCode (NZBC) material and includes exact evidence quotes with page -level S3 links in the form, \nenabling direct verification. When evidence was insufficient, the system stated limitations rather \nthan guessing. End -to-end latency was acceptable for proof -of-concept, with generation time \ncontributing most variability. Overall, the prototype demonstrates that an evidence-grounded RAG \nassistant can act as a practical navigation layer over compliance documents, while highlighting \nthe need for continued work on retrieval coverage, ambiguity handling, and larger-scale validation.'
